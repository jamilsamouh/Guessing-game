# %%
print("WELCOME TO GUESS ME!")
print("I'm thinking of a number between 1 and 100")
print("If your guess is more than 10 away from my number, I'll tell you you're COLD")
print("If your guess is within 10 of my number, I'll tell you you're WARM")
print("If your guess is farther than your most recent guess, I'll say you're getting COLDER")
print("If your guess is closer than your most recent guess, I'll say you're getting WARMER")
print("If your guess is as close as your most recent guess, I'll say you're on SAME HEAT")
print("LET'S PLAY!")
from random import randint
game_guess=randint(1,100)
number_of_guesses=0
mylist=[]
for i in range(0,20):
    player_guess=int(input ("Guess a number between 1 and 100:"))
    number_of_guesses+=1
    while player_guess<1 or player_guess>100:
        print ("OUT OF BONDS!")
        player_guess=int(input ("Guess a number between 1 and 100:"))
        number_of_guesses+=1
    if player_guess==game_guess:
        print (f"\n\tCongratulation on winning!! \n\tyour guess is {player_guess} \n\tyour number of guesses is  {number_of_guesses}")
        break
    elif abs(player_guess-game_guess)<=10 :
        if i==0:
            print ("WARM!")
            last_guess=player_guess
        else:
            if abs(player_guess-game_guess)<abs(last_guess-game_guess):
                print ("GETTING WARMER!")
                last_guess=player_guess
            elif abs(player_guess-game_guess)>abs(last_guess-game_guess) :
                print ("GETTING COLDER!")
                last_guess=player_guess
            elif abs(player_guess-game_guess)==abs(last_guess-game_guess) and last_guess==player_guess:
                print ("WARM!")
                last_guess=player_guess 
            else:  
                print ("SAME HEAT!")
                last_guess=player_guess 
            
                
            
    else: 
        if i==0:
            print ("COLD!")
            last_guess=player_guess
        else:
            if abs(player_guess-game_guess)<abs(last_guess-game_guess):
                print ("GETTING WARMER!")
                last_guess=player_guess
            elif abs(player_guess-game_guess)>abs(last_guess-game_guess) :
                print ("GETTING COLDER!")
                last_guess=player_guess
            elif abs(player_guess-game_guess)==abs(last_guess-game_guess) and last_guess==player_guess:
                print ("COLD!")
                last_guess=player_guess 
            else:  
                print ("SAME HEAT!")
                last_guess=player_guess 
               
        
        
if number_of_guesses==20 :
    print ("You Have Lost!!!")
    print(f"The guess was {game_guess}")
# Out:
# WELCOME TO GUESS ME!
# I'm thinking of a number between 1 and 100
# If your guess is more than 10 away from my number, I'll tell you you're COLD
# If your guess is within 10 of my number, I'll tell you you're WARM
# If your guess is farther than your most recent guess, I'll say you're getting COLDER
# If your guess is closer than your most recent guess, I'll say you're getting WARMER
# If your guess is as close as your most recent guess, I'll say you're on SAME HEAT
# LET'S PLAY!
# Guess a number between 1 and 100:12
# WARM!
# Guess a number between 1 and 100:3
# GETTING COLDER!
# Guess a number between 1 and 100:4
# GETTING WARMER!
# Guess a number between 1 and 100:5
# GETTING WARMER!
# Guess a number between 1 and 100:6
# GETTING WARMER!
# Guess a number between 1 and 100:6
# COLD!
# Guess a number between 1 and 100:6
# COLD!
# Guess a number between 1 and 100:6
# COLD!
# Guess a number between 1 and 100:6
# COLD!
# Guess a number between 1 and 100:6
# COLD!
# ...
